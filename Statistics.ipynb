# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("stats/pilot-unet-v1.csv")

# %%
loss = np.array(df["loss"])
mu = loss.mean()
sigma = loss.std()
print(mu, sigma)
count, bins, ignored = plt.hist(loss, 100, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ), linewidth=2, color='r')
plt.title("Loss distribution")
plt.xlabel("Loss")
plt.ylabel("Frequency")
plt.show()
# Out:
# 3283.138228296869 2258.887868339384

# %%
means = np.array([loss[np.random.randint(low=0, high=len(loss), size=len(loss))].mean() for _ in range(10000)])
mu = means.mean()
sigma = means.std()
print(mu, sigma)
count, bins, ignored = plt.hist(means, 100, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ), linewidth=2, color='r')
plt.title("Mean loss distribution")
plt.xlabel("Loss")
plt.ylabel("Frequency")
plt.show()
# Out:
# 3283.149522235686 124.30855858819608
